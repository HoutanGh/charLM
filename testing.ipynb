# %%
import torch
from charLM import create_dataset
from plotting_fncs import plot_bigram
# %matplotlib inline

training_dataset, testing_dataset = create_dataset("names.txt")

training_dataset
# Out:
# number of words in dataset: 32033
# max word length: 15
# number of unique characters: 27
# vocabulary: .abcdefghijklmnopqrstuvwxyz
# number of training words: 28830
# number of testing words: 3203

# %%
plot_bigram(training_dataset)
